# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AzlanFaisalRaj/flyrank-internship-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# # My Lane: Content Refresh Prioritization
#
# I chose the Content Refresh Prioritization lane because websites often contain many pages, but not all need updates at the same time. My goal is to identify which pages should be reviewed first based on their search performance and engagement signals. This project can help content editors focus on the most important pages instead of reviewing every page manually.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Decision
#
# The decision is to identify which content pages should be refreshed first based on their search performance.
#
# ## Who Takes Action?
#
# The output will be used by content editors or SEO managers to decide which pages should be updated first.
#
# ## Cost of a Wrong Recommendation
#
# If the model recommends the wrong pages, editors may waste time updating content that does not need attention. At the same time, important declining pages may be missed, causing further loss of search traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains anonymized search performance data for content pages. I will examine the total number of pages, the number of columns, and the percentage of declining pages to understand why this problem is worth solving.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

declining = (df["trend_direction"].str.lower() == "down").sum()

print("Declining Pages:", declining)
print("Declining Percentage:", round(declining / len(df) * 100, 2), "%")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2902/1653994916.py in <cell line: 0>()
#       3 import pandas as pd
#       4
# ----> 5 df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
#       6
#       7 print("Rows:", df.shape[0])
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project provides decision-support based on observed search data. It can identify patterns and help prioritize content for review. However, it does not prove why rankings change, does not predict Google's algorithm, and does not establish cause-and-effect relationships. The results should be interpreted as observed and directional only.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
